# %% [markdown]
# #### Método ABCDE
#
# A - Assets (recursos: imagens, vídeos, paletas de cores, texto)
#
# B - Bases (dados para gerar a dashboard principal ou outra medidas)
#
# C - Cálculos (processamento de dados para transformar em informações)
#
# D- Dashboard (Painél visual)
#
# E - Extras
